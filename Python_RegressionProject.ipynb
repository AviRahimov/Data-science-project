# %% [markdown]
# # The research question is To predict the Acceleration based on Displacement,Horsepower, Miles_per_Gallon,Weight_in_kg

# %% [markdown]
# ## Importing all the libaries we are going to use

# %%
import pandas as pd
import numpy as np
import json
import urllib
import matplotlib as mp
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from pandas.plotting import scatter_matrix
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, KFold, GridSearchCV

# %% [markdown]
# ## Webscrapping the data

# %%
url = "https://raw.githubusercontent.com/vega/vega/master/docs/data/cars.json"
response = urllib.request.urlopen(url)
data = json.loads(response.read())
df = pd.DataFrame(data)
df
# Out:
#      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0            12.0          8         307.0       130.0              18.0
# 1            11.5          8         350.0       165.0              15.0
# 2            11.0          8         318.0       150.0              18.0
# 3            12.0          8         304.0       150.0              16.0
# 4            10.5          8         302.0       140.0              17.0
# 5            10.0          8         429.0       198.0              15.0
# 6             9.0          8         454.0       220.0              14.0
# 7             8.5          8         440.0       215.0              14.0
# 8            10.0          8         455.0       225.0              14.0
# 9             8.5          8         390.0       190.0              15.0
# 10           17.5          4         133.0       115.0               NaN
# 11           11.5          8         350.0       165.0               NaN
# 12           11.0          8         351.0       153.0               NaN
# 13           10.5          8         383.0       175.0               NaN
# 14           11.0          8         360.0       175.0               NaN
# 15           10.0          8         383.0       170.0              15.0
# 16            8.0          8         340.0       160.0              14.0
# 17            8.0          8         302.0       140.0               NaN
# 18            9.5          8         400.0       150.0              15.0
# 19           10.0          8         455.0       225.0              14.0
# 20           15.0          4         113.0        95.0              24.0
# 21           15.5          6         198.0        95.0              22.0
# 22           15.5          6         199.0        97.0              18.0
# 23           16.0          6         200.0        85.0              21.0
# 24           14.5          4          97.0        88.0              27.0
# 25           20.5          4          97.0        46.0              26.0
# 26           17.5          4         110.0        87.0              25.0
# 27           14.5          4         107.0        90.0              24.0
# 28           17.5          4         104.0        95.0              25.0
# 29           12.5          4         121.0       113.0              26.0
# ..            ...        ...           ...         ...               ...
# 376          18.6          4         112.0        88.0              27.0
# 377          18.0          4         112.0        88.0              34.0
# 378          16.2          4         112.0        85.0              31.0
# 379          16.0          4         135.0        84.0              29.0
# 380          18.0          4         151.0        90.0              27.0
# 381          16.4          4         140.0        92.0              24.0
# 382          20.5          4         151.0         NaN              23.0
# 383          15.3          4         105.0        74.0              36.0
# 384          18.2          4          91.0        68.0              37.0
# 385          17.6          4          91.0        68.0              31.0
# 386          14.7          4         105.0        63.0              38.0
# 387          17.3          4          98.0        70.0              36.0
# 388          14.5          4         120.0        88.0              36.0
# 389          14.5          4         107.0        75.0              36.0
# 390          16.9          4         108.0        70.0              34.0
# 391          15.0          4          91.0        67.0              38.0
# 392          15.7          4          91.0        67.0              32.0
# 393          16.2          4          91.0        67.0              38.0
# 394          16.4          6         181.0       110.0              25.0
# 395          17.0          6         262.0        85.0              38.0
# 396          14.5          4         156.0        92.0              26.0
# 397          14.7          6         232.0       112.0              22.0
# 398          13.9          4         144.0        96.0              32.0
# 399          13.0          4         135.0        84.0              36.0
# 400          17.3          4         151.0        90.0              27.0
# 401          15.6          4         140.0        86.0              27.0
# 402          24.6          4          97.0        52.0              44.0
# 403          11.6          4         135.0        84.0              32.0
# 404          18.6          4         120.0        79.0              28.0
# 405          19.4          4         119.0        82.0              31.0
#
#                                   Name  Origin  Weight_in_lbs        Year
# 0            chevrolet chevelle malibu     USA           3504  1970-01-01
# 1                    buick skylark 320     USA           3693  1970-01-01
# 2                   plymouth satellite     USA           3436  1970-01-01
# 3                        amc rebel sst     USA           3433  1970-01-01
# 4                          ford torino     USA           3449  1970-01-01
# 5                     ford galaxie 500     USA           4341  1970-01-01
# 6                     chevrolet impala     USA           4354  1970-01-01
# 7                    plymouth fury iii     USA           4312  1970-01-01
# 8                     pontiac catalina     USA           4425  1970-01-01
# 9                   amc ambassador dpl     USA           3850  1970-01-01
# 10                citroen ds-21 pallas  Europe           3090  1970-01-01
# 11    chevrolet chevelle concours (sw)     USA           4142  1970-01-01
# 12                    ford torino (sw)     USA           4034  1970-01-01
# 13             plymouth satellite (sw)     USA           4166  1970-01-01
# 14                  amc rebel sst (sw)     USA           3850  1970-01-01
# 15                 dodge challenger se     USA           3563  1970-01-01
# 16                  plymouth 'cuda 340     USA           3609  1970-01-01
# 17               ford mustang boss 302     USA           3353  1970-01-01
# 18               chevrolet monte carlo     USA           3761  1970-01-01
# 19             buick estate wagon (sw)     USA           3086  1970-01-01
# 20               toyota corona mark ii   Japan           2372  1970-01-01
# 21                     plymouth duster     USA           2833  1970-01-01
# 22                          amc hornet     USA           2774  1970-01-01
# 23                       ford maverick     USA           2587  1970-01-01
# 24                        datsun pl510   Japan           2130  1970-01-01
# 25        volkswagen 1131 deluxe sedan  Europe           1835  1970-01-01
# 26                         peugeot 504  Europe           2672  1970-01-01
# 27                         audi 100 ls  Europe           2430  1970-01-01
# 28                            saab 99e  Europe           2375  1970-01-01
# 29                            bmw 2002  Europe           2234  1970-01-01
# ..                                 ...     ...            ...         ...
# 376           chevrolet cavalier wagon     USA           2640  1982-01-01
# 377          chevrolet cavalier 2-door     USA           2395  1982-01-01
# 378         pontiac j2000 se hatchback     USA           2575  1982-01-01
# 379                     dodge aries se     USA           2525  1982-01-01
# 380                    pontiac phoenix     USA           2735  1982-01-01
# 381               ford fairmont futura     USA           2865  1982-01-01
# 382                     amc concord dl     USA           3035  1982-01-01
# 383                volkswagen rabbit l  Europe           1980  1982-01-01
# 384                 mazda glc custom l   Japan           2025  1982-01-01
# 385                   mazda glc custom   Japan           1970  1982-01-01
# 386             plymouth horizon miser     USA           2125  1982-01-01
# 387                     mercury lynx l     USA           2125  1982-01-01
# 388                   nissan stanza xe   Japan           2160  1982-01-01
# 389              honda Accelerationord   Japan           2205  1982-01-01
# 390                     toyota corolla   Japan           2245  1982-01-01
# 391                        honda civic   Japan           1965  1982-01-01
# 392                 honda civic (auto)   Japan           1965  1982-01-01
# 393                      datsun 310 gx   Japan           1995  1982-01-01
# 394              buick century limited     USA           2945  1982-01-01
# 395  oldsmobile cutlass ciera (diesel)     USA           3015  1982-01-01
# 396         chrysler lebaron medallion     USA           2585  1982-01-01
# 397                     ford granada l     USA           2835  1982-01-01
# 398                   toyota celica gt   Japan           2665  1982-01-01
# 399                  dodge charger 2.2     USA           2370  1982-01-01
# 400                   chevrolet camaro     USA           2950  1982-01-01
# 401                    ford mustang gl     USA           2790  1982-01-01
# 402                          vw pickup  Europe           2130  1982-01-01
# 403                      dodge rampage     USA           2295  1982-01-01
# 404                        ford ranger     USA           2625  1982-01-01
# 405                         chevy s-10     USA           2720  1982-01-01
#
# [406 rows x 9 columns]

# %% [markdown]
# # information about the Data
# #### Aceleration: Amount of time it takes to reach 96.56 km/h from 0 km/h, in seconds.
# #### Cylinders: Number of cylinders in the car's engine.
# #### Displacement: The engine volume, in cubic centimeter.
# #### Horsepower: The amount of power the engine produce, in horsepower.
# #### Miles_per_Gallon: the fuel economy of the vehicle, in miles per gallon(i will change it to kilometers per gallon).
# #### Name: vehicle company and model.
# #### Origin: origin of the company.
# #### Year: Year of production.
#
# #### *There is no turbo in the engines of these vehicles.

# %% [markdown]
# ## Deviding the data to train and test sets

# %%
train_set, test_set = train_test_split(df,test_size=0.2, random_state=23)

# %% [markdown]
# ## cleaning the train_set

# %% [markdown]
# #### erasing duplicates rows(duplicate cars)

# %%
train_set.drop_duplicates()
# Out:
#      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 266          16.7          6         200.0        85.0              20.8
# 74           11.0          8         429.0       208.0              11.0
# 375          19.6          4         112.0        88.0              28.0
# 294          13.2          8         351.0       138.0              16.5
# 385          17.6          4          91.0        68.0              31.0
# 378          16.2          4         112.0        85.0              31.0
# 175          17.0          4         140.0        83.0              23.0
# 359          20.7          4          98.0        65.0              29.9
# 337          17.3          4          85.0         NaN              40.9
# 135          17.0          6         250.0       100.0              15.0
# 301          15.2          4          86.0        65.0              34.1
# 46           11.5          8         400.0       175.0              14.0
# 172          13.5          8         262.0       110.0              20.0
# 185          17.0          4         120.0        88.0              23.0
# 380          18.0          4         151.0        90.0              27.0
# 193          15.3          4         101.0        83.0              27.0
# 77           12.5          8         400.0       190.0              13.0
# 226          15.5          4         122.0        96.0              25.5
# 58           19.5          4          79.0        70.0              30.0
# 29           12.5          4         121.0       113.0              26.0
# 349          12.9          4         135.0        84.0              30.0
# 176          16.0          6         232.0       100.0              20.0
# 167          21.0          6         231.0       110.0              17.0
# 101          11.0          8         440.0       215.0              13.0
# 115          19.0          4          97.0        88.0              20.0
# 398          13.9          4         144.0        96.0              32.0
# 44           15.5          6         232.0       100.0              18.0
# 329          17.9          4          86.0        65.0              46.6
# 320          16.5          4         151.0        90.0              28.0
# 165          14.5          8         318.0       150.0              16.0
# ..            ...        ...           ...         ...               ...
# 15           10.0          8         383.0       170.0              15.0
# 171          15.0          6         231.0       110.0              21.0
# 372          19.0          8         350.0       105.0              26.6
# 65           17.0          4          97.5        80.0              25.0
# 36           15.5          4         140.0        90.0              28.0
# 399          13.0          4         135.0        84.0              36.0
# 187          13.5          4         121.0       115.0              25.0
# 57           14.0          4         116.0        90.0              28.0
# 346          16.4          4         151.0        84.0              26.6
# 79           12.5          8         304.0       150.0              15.0
# 297          14.3          8         351.0       142.0              15.5
# 48           13.0          8         318.0       150.0              14.0
# 21           15.5          6         198.0        95.0              22.0
# 394          16.4          6         181.0       110.0              25.0
# 192          17.7          4          98.0        79.0              26.0
# 197          12.8          8         351.0       152.0              14.5
# 194          13.0          8         305.0       140.0              17.5
# 49           11.5          8         383.0       180.0              12.0
# 12           11.0          8         351.0       153.0               NaN
# 379          16.0          4         135.0        84.0              29.0
# 6             9.0          8         454.0       220.0              14.0
# 153          14.5          4          90.0        75.0              28.0
# 90           15.0          4          98.0        80.0              28.0
# 39           20.0          4          97.0        48.0               NaN
# 347          14.4          4         156.0        92.0              25.8
# 237          11.4          8         350.0       170.0              15.5
# 31           14.0          8         360.0       215.0              10.0
# 40           13.0          6         232.0       100.0              19.0
# 230          13.7          8         318.0       145.0              15.5
# 83           14.5          4         121.0       112.0              18.0
#
#                                   Name  Origin  Weight_in_lbs        Year
# 266                     mercury zephyr     USA           3070  1978-01-01
# 74                     mercury marquis     USA           4633  1972-01-01
# 375                 chevrolet cavalier     USA           2605  1982-01-01
# 294              mercury grand marquis     USA           3955  1979-01-01
# 385                   mazda glc custom   Japan           1970  1982-01-01
# 378         pontiac j2000 se hatchback     USA           2575  1982-01-01
# 175                         ford pinto     USA           2639  1975-01-01
# 359                     ford escort 2h     USA           2380  1982-01-01
# 337               renault lecar deluxe  Europe           1835  1980-01-01
# 135                     chevrolet nova     USA           3336  1974-01-01
# 301                   maxda glc deluxe   Japan           1975  1979-01-01
# 46           pontiac catalina brougham     USA           4464  1971-01-01
# 172                chevrolet monza 2+2     USA           3221  1975-01-01
# 185                        peugeot 504  Europe           2957  1975-01-01
# 380                    pontiac phoenix     USA           2735  1982-01-01
# 193                       renault 12tl  Europe           2202  1976-01-01
# 77              chrysler newport royal     USA           4422  1972-01-01
# 226                  plymouth arrow gs     USA           2300  1977-01-01
# 58                         peugeot 304  Europe           2074  1971-01-01
# 29                            bmw 2002  Europe           2234  1970-01-01
# 349                   plymouth reliant     USA           2385  1982-01-01
# 176                        amc gremlin     USA           2914  1975-01-01
# 167                      buick century     USA           3907  1975-01-01
# 101       chrysler new yorker brougham     USA           4735  1973-01-01
# 115                      toyota carina   Japan           2279  1973-01-01
# 398                   toyota celica gt   Japan           2665  1982-01-01
# 44                         amc matador     USA           3288  1971-01-01
# 329                          mazda glc   Japan           2110  1980-01-01
# 320                 chevrolet citation     USA           2678  1980-01-01
# 165                plymouth grand fury     USA           4498  1975-01-01
# ..                                 ...     ...            ...         ...
# 15                 dodge challenger se     USA           3563  1970-01-01
# 171                      buick skyhawk     USA           3039  1975-01-01
# 372              oldsmobile cutlass ls     USA           3725  1982-01-01
# 65                  dodge colt hardtop     USA           2126  1972-01-01
# 36                 chevrolet vega 2300     USA           2264  1971-01-01
# 399                  dodge charger 2.2     USA           2370  1982-01-01
# 187                          saab 99le  Europe           2671  1975-01-01
# 57                           opel 1900  Europe           2123  1971-01-01
# 346                      buick skylark     USA           2635  1982-01-01
# 79                    amc matador (sw)     USA           3892  1972-01-01
# 297           ford country squire (sw)     USA           4054  1979-01-01
# 48                   plymouth fury iii     USA           4096  1971-01-01
# 21                     plymouth duster     USA           2833  1970-01-01
# 394              buick century limited     USA           2945  1982-01-01
# 192                         dodge colt     USA           2255  1976-01-01
# 197                   ford gran torino     USA           4215  1976-01-01
# 194  chevrolet chevelle malibu classic     USA           4215  1976-01-01
# 49                   dodge monaco (sw)     USA           4955  1971-01-01
# 12                    ford torino (sw)     USA           4034  1970-01-01
# 379                     dodge aries se     USA           2525  1982-01-01
# 6                     chevrolet impala     USA           4354  1970-01-01
# 153                         dodge colt     USA           2125  1974-01-01
# 90                     dodge colt (sw)     USA           2164  1972-01-01
# 39         volkswagen super beetle 117  Europe           1978  1971-01-01
# 347             dodge aries wagon (sw)     USA           2620  1982-01-01
# 237       chevrolet monte carlo landau     USA           4165  1977-01-01
# 31                           ford f250     USA           4615  1970-01-01
# 40                         amc gremlin     USA           2634  1971-01-01
# 230              dodge monaco brougham     USA           4140  1977-01-01
# 83                     volvo 145e (sw)  Europe           2933  1972-01-01
#
# [324 rows x 9 columns]

# %% [markdown]
# #### checking for null values in the data and erasing those rows

# %%
train_set.isnull().sum()
# Out:
# Acceleration        0
# Cylinders           0
# Displacement        0
# Horsepower          5
# Miles_per_Gallon    6
# Name                0
# Origin              0
# Weight_in_lbs       0
# Year                0
# dtype: int64

# %%
train_set = train_set.dropna(how='any',axis=0)
train_set.isnull().sum()
# Out:
# Acceleration        0
# Cylinders           0
# Displacement        0
# Horsepower          0
# Miles_per_Gallon    0
# Name                0
# Origin              0
# Weight_in_lbs       0
# Year                0
# dtype: int64

# %% [markdown]
# #### converting the data from US measurements to IL measurements

# %%
train_set = train_set.sort_values(by="Acceleration", ascending=True)
train_set.rename({'Weight_in_lbs': 'Weight_in_Kg', 'Miles_per_Gallon': 'Kilometers_per_Gallon'}, axis=1, inplace=True)

train_set['Weight_in_Kg'] = train_set['Weight_in_Kg'].apply(lambda x: int(x*0.45359237))
train_set['Kilometers_per_Gallon'] = train_set['Kilometers_per_Gallon'].apply(lambda x: int(x*1.609344))
train_set.drop(['Name', 'Origin', 'Year'], axis=1, inplace=True)
train_set.head()
# Out:
#     Acceleration  Cylinders  Displacement  Horsepower  Kilometers_per_Gallon  \
# 16           8.0          8         340.0       160.0                     22
# 7            8.5          8         440.0       215.0                     22
# 9            8.5          8         390.0       190.0                     24
# 6            9.0          8         454.0       220.0                     22
# 5           10.0          8         429.0       198.0                     24
#
#     Weight_in_Kg
# 16          1637
# 7           1955
# 9           1746
# 6           1974
# 5           1969

# %% [markdown]
# ## cleaning the test_set

# %% [markdown]
# #### erasing duplicates rows(duplicate cars)

# %%
test_set.drop_duplicates()
# Out:
#      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 286          16.6          4          98.0        68.0              29.5
# 217          15.5          6         156.0       108.0              19.0
# 401          15.6          4         140.0        86.0              27.0
# 281          15.9          5         131.0       103.0              20.3
# 108          16.0          6         198.0        95.0              23.0
# 139          17.0          4         140.0        75.0              25.0
# 275          14.7          4         119.0        97.0              27.2
# 195          13.0          8         318.0       150.0              16.0
# 273          16.5          4          98.0        68.0              30.0
# 174          16.0          4          97.0        75.0              29.0
# 168          18.5          6         250.0       105.0              16.0
# 201          17.6          6         232.0        90.0              22.5
# 123           9.5          8         400.0       230.0              16.0
# 69           12.0          8         350.0       165.0              13.0
# 14           11.0          8         360.0       175.0               NaN
# 238          12.2          8         400.0       190.0              15.5
# 88           17.0          4          97.0        92.0              28.0
# 222          14.0          8         318.0       150.0              13.0
# 251          21.5          4          90.0        48.0              43.1
# 110          14.0          8         400.0       150.0              11.0
# 94           13.0          8         350.0       145.0              13.0
# 365          18.3          4         120.0        74.0              31.6
# 390          16.9          4         108.0        70.0              34.0
# 327          15.0          4         119.0        92.0              37.0
# 351          16.4          4          86.0        64.0              39.0
# 91           16.5          4          97.0        88.0              27.0
# 190          16.9          4         116.0        81.0              25.0
# 328          15.2          4         108.0        75.0              32.2
# 303          15.0          4         121.0        80.0              27.4
# 145          13.5          8         318.0       150.0              14.0
# ..            ...        ...           ...         ...               ...
# 112          13.0          8         360.0       170.0              13.0
# 182          14.0          4          90.0        70.0              29.0
# 122          13.0          8         350.0       145.0              15.0
# 213          13.6          4         140.0        72.0              26.5
# 117          16.5          4         108.0        94.0              22.0
# 233          16.9          6         231.0       105.0              20.5
# 179          16.5          4          90.0        71.0              25.0
# 140          17.0          6         250.0       100.0              16.0
# 293          13.4          8         302.0       129.0              17.6
# 2            11.0          8         318.0       150.0              18.0
# 13           10.5          8         383.0       175.0               NaN
# 296          14.9          8         350.0       155.0              16.9
# 73           11.5          8         304.0       150.0              17.0
# 305          17.4          8         350.0       125.0              23.0
# 389          14.5          4         107.0        75.0              36.0
# 95           14.5          8         302.0       137.0              14.0
# 308          13.2          4         105.0        70.0              34.2
# 27           14.5          4         107.0        90.0              24.0
# 270          13.4          6         231.0       165.0              17.7
# 158          16.0          4          79.0        67.0              31.0
# 258          12.8          8         302.0       139.0              20.2
# 290          18.2          6         232.0        90.0              20.2
# 280          14.9          4         119.0        97.0              23.9
# 203          22.1          4          98.0        60.0              24.5
# 151          16.5          4          76.0        52.0              31.0
# 239          14.5          8         351.0       149.0              16.0
# 43           15.5          6         250.0        88.0              19.0
# 8            10.0          8         455.0       225.0              14.0
# 45           12.0          8         350.0       165.0              14.0
# 325          15.5          4         134.0        90.0              29.8
#
#                                   Name  Origin  Weight_in_lbs        Year
# 286           honda Accelerationord lx   Japan           2135  1978-01-01
# 217                     toyota mark ii   Japan           2930  1976-01-01
# 401                    ford mustang gl     USA           2790  1982-01-01
# 281                          audi 5000  Europe           2830  1978-01-01
# 108                    plymouth duster     USA           2904  1973-01-01
# 139                     chevrolet vega     USA           2542  1974-01-01
# 275                         datsun 510   Japan           2300  1978-01-01
# 195             dodge coronet brougham     USA           4190  1976-01-01
# 273                 chevrolet chevette     USA           2155  1978-01-01
# 174                     toyota corolla   Japan           2171  1975-01-01
# 168          chevroelt chevelle malibu     USA           3897  1975-01-01
# 201                         amc hornet     USA           3085  1976-01-01
# 123                 pontiac grand prix     USA           4278  1973-01-01
# 69                    chevrolet impala     USA           4274  1972-01-01
# 14                  amc rebel sst (sw)     USA           3850  1970-01-01
# 238                   chrysler cordoba     USA           4325  1977-01-01
# 88                     datsun 510 (sw)   Japan           2288  1972-01-01
# 222                         dodge d100     USA           3755  1976-01-01
# 251    volkswagen rabbit custom diesel  Europe           1985  1978-01-01
# 110                   chevrolet impala     USA           4997  1973-01-01
# 94                    chevrolet malibu     USA           3988  1973-01-01
# 365                          mazda 626   Japan           2635  1982-01-01
# 390                     toyota corolla   Japan           2245  1982-01-01
# 327               datsun 510 hatchback   Japan           2434  1980-01-01
# 351                     plymouth champ     USA           1875  1982-01-01
# 91            toyota corolla 1600 (sw)   Japan           2100  1972-01-01
# 190                          opel 1900  Europe           2220  1976-01-01
# 328                     toyota corolla   Japan           2265  1980-01-01
# 303                      amc spirit dl     USA           2670  1979-01-01
# 145          dodge coronet custom (sw)     USA           4457  1974-01-01
# ..                                 ...     ...            ...         ...
# 112             plymouth custom suburb     USA           4654  1973-01-01
# 182                  volkswagen rabbit  Europe           1937  1975-01-01
# 122            chevrolet monte carlo s     USA           4082  1973-01-01
# 213                         ford pinto     USA           2565  1976-01-01
# 117                         datsun 610   Japan           2379  1973-01-01
# 233                      buick skylark     USA           3425  1977-01-01
# 179                  volkswagen dasher  Europe           2223  1975-01-01
# 140  chevrolet chevelle malibu classic     USA           3781  1974-01-01
# 293                    ford ltd landau     USA           3725  1979-01-01
# 2                   plymouth satellite     USA           3436  1970-01-01
# 13             plymouth satellite (sw)     USA           4166  1970-01-01
# 296            buick estate wagon (sw)     USA           4360  1979-01-01
# 73                  amc ambassador sst     USA           3672  1972-01-01
# 305                  cadillac eldorado     USA           3900  1979-01-01
# 389              honda Accelerationord   Japan           2205  1982-01-01
# 95                    ford gran torino     USA           4042  1973-01-01
# 308                   plymouth horizon     USA           2200  1979-01-01
# 27                         audi 100 ls  Europe           2430  1970-01-01
# 270    buick regal sport coupe (turbo)     USA           3445  1978-01-01
# 158                          fiat x1.9  Europe           2000  1974-01-01
# 258               mercury monarch ghia     USA           3570  1978-01-01
# 290                   amc concord dl 6     USA           3265  1979-01-01
# 280                      datsun 200-sx   Japan           2405  1978-01-01
# 203                    chevrolet woody     USA           2164  1976-01-01
# 151                      toyota corona   Japan           1649  1974-01-01
# 239                   ford thunderbird     USA           4335  1977-01-01
# 43                     ford torino 500     USA           3302  1971-01-01
# 8                     pontiac catalina     USA           4425  1970-01-01
# 45                    chevrolet impala     USA           4209  1971-01-01
# 325             toyota corona liftback   Japan           2711  1980-01-01
#
# [82 rows x 9 columns]

# %% [markdown]
# #### checking for null values in the data and erasing those rows

# %%
test_set.isnull().sum()
# Out:
# Acceleration        0
# Cylinders           0
# Displacement        0
# Horsepower          1
# Miles_per_Gallon    2
# Name                0
# Origin              0
# Weight_in_lbs       0
# Year                0
# dtype: int64

# %%
test_set = test_set.dropna(how='any',axis=0)
test_set.isnull().sum()
# Out:
# Acceleration        0
# Cylinders           0
# Displacement        0
# Horsepower          0
# Miles_per_Gallon    0
# Name                0
# Origin              0
# Weight_in_lbs       0
# Year                0
# dtype: int64

# %% [markdown]
# #### converting the data from US measurements to IL measurements

# %%
test_set = test_set.sort_values(by="Acceleration", ascending=True)
test_set.rename({'Weight_in_lbs': 'Weight_in_Kg', 'Miles_per_Gallon': 'Kilometers_per_Gallon'}, axis=1, inplace=True)

test_set['Weight_in_Kg'] = test_set['Weight_in_Kg'].apply(lambda x: int(x*0.45359237))
test_set['Kilometers_per_Gallon'] = test_set['Kilometers_per_Gallon'].apply(lambda x: int(x*1.609344))
test_set.drop(['Name', 'Origin', 'Year'], axis=1, inplace=True)

# %% [markdown]
# ## Inspecting the data

# %%
train_set.describe()
# Out:
#        Acceleration   Cylinders  Displacement  Horsepower  \
# count    313.000000  313.000000    313.000000  313.000000
# mean      15.545367    5.431310    192.017572  103.942492
# std        2.736222    1.687789    103.023276   37.724667
# min        8.000000    3.000000     68.000000   46.000000
# 25%       13.800000    4.000000    101.000000   78.000000
# 50%       15.500000    4.000000    151.000000   95.000000
# 75%       17.300000    6.000000    260.000000  120.000000
# max       24.800000    8.000000    455.000000  225.000000
#
#        Kilometers_per_Gallon  Weight_in_Kg
# count             313.000000    313.000000
# mean               37.412141   1340.581470
# std                12.639964    380.131321
# min                16.000000    731.000000
# 25%                28.000000   1006.000000
# 50%                36.000000   1265.000000
# 75%                46.000000   1603.000000
# max                74.000000   2331.000000

# %% [markdown]
#  ## Looking for connection between the variables to the Acceleration

# %%
sns.pairplot(train_set, x_vars=['Cylinders', 'Displacement', 'Horsepower', 'Kilometers_per_Gallon', 'Weight_in_Kg'], y_vars='Acceleration', 
             size=10, aspect = 0.7, kind='reg')

# %%
sns.heatmap(train_set.corr())

# %%
scatter_matrix(train_set, figsize=(18, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000221F3F2F5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F3F5EDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F3F90438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F3FB6AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F3FE6198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F3FE61D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4037EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4065588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F408DC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F40BF2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F40E4978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4117048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000221F413F6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4167D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4197438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F41C0AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F41F0198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4216828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000221F423EEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4272588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4656C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F46882E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F46B1978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F46E0048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000221F47086D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4732D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4762438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F4789AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F47BB198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F47E1828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000221F484AEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F487D588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F48A1C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F48D32E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F48F9978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221F49EE048>]],
#       dtype=object)

# %% [markdown]
# #### From the scatter matrix we can infer that there is not strong connection between the Cylinders and the other features of the vehicles

# %%
train_set.drop(['Cylinders'], axis=1, inplace=True)
test_set.drop(['Cylinders'], axis=1, inplace=True)

# %% [markdown]
# # building 3 different models for Regression

# %% [markdown]
# ### Splitting the train set to x,y of the set.

# %%
x_train = train_set[['Displacement', 'Horsepower', 'Kilometers_per_Gallon', 'Weight_in_Kg']]
y_train = train_set['Acceleration']

# %%
folds = KFold(n_splits = 4, shuffle = True, random_state = 42)

# %% [markdown]
# ### Linear Regression model

# %%
linear_reg = linear_model.LinearRegression()

# %%
l_scores = cross_val_score(linear_reg, x_train, y_train, scoring='r2', cv=folds)
print(l_scores)
np.mean(l_scores)
# Out:
# [0.46075531 0.56107003 0.7250755  0.65762021]
# 0.6011302612047178

# %% [markdown]
# ### KNeighborsRegressor model

# %%
knn_reg = KNeighborsRegressor()
knn_scores = cross_val_score(knn_reg, x_train, y_train, scoring='r2', cv=folds)
print(knn_scores)
np.mean(knn_scores)
# Out:
# [0.35345652 0.3414517  0.50366911 0.45588367]
# 0.41361525022762935

# %%
k_range = range(1, 40)
k_scores = []

for k in k_range:
    knn_reg = KNeighborsRegressor(n_neighbors=k)
    scores = cross_val_score(knn_reg, x_train, y_train, cv=folds, scoring='r2')
    k_scores.append(scores.mean())

plt.plot(k_range, k_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
plt.show()

# %% [markdown]
# ### Decision Tree model

# %%
params_dict = {"max_depth":range(2,15), "min_samples_leaf":range(2,15), "min_samples_split": range(2,15)}
dt_reg = DecisionTreeRegressor(random_state=42)

grid = GridSearchCV(dt_reg, params_dict, cv=folds)
grid.fit(x_train,y_train)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 11, 'min_samples_leaf': 3, 'min_samples_split': 8}
# 0.6295319344819165

# %%
dt_scores = cross_val_score(dt_reg, x_train, y_train, scoring='r2', cv=folds)
print(dt_scores)
np.mean(dt_scores)
# Out:
# [0.52606118 0.19452821 0.67889173 0.52834852]
# 0.48195741197570635

# %% [markdown]
# #### We see that the highest score is from the gridsearch and not the cross validation

# %% [markdown]
# # Selecting the model with the highest(DecisionTreeRegressor model) accuracy and trying to improve it's accuracy

# %% [markdown]
# ### Log Transformation for Horsepower, Displacement, Kilometers_per_Gallon, Weight_in_Kg

# %%
x_train['HP_Impact'] = np.log(x_train['Horsepower'])
x_train['Displacement_Impact'] = np.log(x_train['Displacement'])
x_train['Kilometers_per_Gallon_Impact'] = np.log(x_train['Kilometers_per_Gallon'])
x_train['Weight_in_Kg_Impact'] = np.log(x_train['Weight_in_Kg'])

new_train = x_train
new_train['Acceleration'] = y_train

test_set['HP_Impact'] = np.log(test_set['Horsepower'])
test_set['Displacement_Impact'] =  np.log(test_set['Displacement'])
test_set['Kilometers_per_Gallon_Impact'] = np.log(test_set['Kilometers_per_Gallon'])
test_set['Weight_in_Kg_Impact'] = np.log(test_set['Weight_in_Kg'])

# %% [markdown]
# #### ploting the log graphs of Horsepower, Displacement, Kilometers_per_Gallon, Weight_in_Kg

# %%
for t in ['HP_Impact', 'Displacement_Impact', 'Kilometers_per_Gallon_Impact', 'Weight_in_Kg_Impact']:
    sns.lmplot(x=t, y='Acceleration', data = new_train, order=1)
    plt.show()

# %% [markdown]
# ### splitting the train set to x_train y_train

# %%
X_train = new_train[['Displacement', 'Horsepower', 'Kilometers_per_Gallon', 'Weight_in_Kg', 
                   'HP_Impact', 'Displacement_Impact', 'Kilometers_per_Gallon_Impact', 'Weight_in_Kg_Impact']]
Y_train = new_train['Acceleration']

# %% [markdown]
# #### Let's check the score of the decision tree model

# %%
dt = DecisionTreeRegressor(random_state=42)
new_grid = GridSearchCV(dt, params_dict, cv=folds)
new_grid.fit(X_train,Y_train)

print(new_grid.best_params_)
print(new_grid.best_score_)
# Out:
# {'max_depth': 11, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.6323492318749374

# %% [markdown]
# #### We tried to improve the DecisionTreeRegressor model and it didn't impact the score much, so let's try to improve the next highest scored model(LinearRegression model)

# %% [markdown]
# ### calculating the score of the model

# %%
scores = cross_val_score(linear_reg, X=X_train, y=Y_train, scoring='r2', cv=folds)
print(scores)
np.mean(scores)
# Out:
# [0.65665636 0.64016122 0.76044492 0.75769401]
# 0.7037391245794788

# %% [markdown]
# #### We can see that the model accuracy did improved and it's higher than the DecisionTreeRegressor model so we will choose the Linear Regression model to be our final model.

# %% [markdown]
# # Testing our model

# %% [markdown]
# ### splitting the test set to x_test y_test

# %%
X_test = test_set[['Displacement', 'Horsepower', 'Kilometers_per_Gallon', 'Weight_in_Kg', 
                   'HP_Impact', 'Displacement_Impact', 'Kilometers_per_Gallon_Impact', 'Weight_in_Kg_Impact']]
Y_test = test_set['Acceleration'].copy()

# %% [markdown]
# ### calculating the final score of our Linear Regression model

# %%
model = linear_reg
model.fit(X_train, Y_train)
final_pred = model.predict(X_test)
final_score = r2_score(Y_test,final_pred)
final_score
# Out:
# 0.6773730235313409
